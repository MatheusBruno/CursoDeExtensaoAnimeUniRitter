# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusBruno/CursoDeExtensaoAnimeUniRitter/blob/main/Tabela%20de%20Pre%C3%A7os%20de%20combustivel%20RS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
combustiveiscanoas = pd.read_excel("combustiveis-2023-02.xlsx")

# %%
display(combustiveiscanoas[['Endereco', 'Numero', 'Bairro ', 'Cep', 'Municipio', 'Estado', 'Produto', 'Price']])
# Out:
#                              Endereco Numero                 Bairro   \
# 0               RUA AMARO CASTRO LIMA   1852  VILA NOVA CAMPO GRANDE
# 1                       AVENIDA CAIRU    989              NAVEGANTES
# 2              RUA HUMBERTO DE CAMPOS    306          JARDIM ZULMIRA
# 3              RUA HUMBERTO DE CAMPOS    306          JARDIM ZULMIRA
# 4              RUA HUMBERTO DE CAMPOS    306          JARDIM ZULMIRA
# ...                               ...    ...                     ...
# 19665                  RODOVIA BR-316   3282                 SALOBRO
# 19666  AVENIDA GOVERNADOR PAULO SOUTO    510         TEOTONIO VILELA
# 19667                AVENIDA SAO JOAO    235              VILA JESSE
# 19668            AVENIDA HENRY BORDEN    600         VILA SANTA ROSA
# 19669               RUA   INÁCIO VALE    248      ALTO DE SÃO MANOEL
#
#             Cep      Municipio               Estado         Produto   Price
# ...

# %%
pricegas = combustiveiscanoas[['Endereco', 'Numero', 'Bairro ', 'Cep', 'Municipio', 'Estado', 'Produto', 'Price']]

# %%
listcombustivelstate = pricegas.loc[(pricegas['Estado'] == 'RIO GRANDE DO SUL') & (pricegas['Produto'] == 'ETANOL') & (pricegas['Price'] < 4.40)]
display(listcombustivelstate)
# Out:
#                               Endereco Numero            Bairro        Cep  \
# 3828                        RUA RINCAO   1110         PETROPOLIS  93346340
# 3836      AVENIDA GENERAL DALTRO FILHO    494     HAMBURGO VELHO  93534034
# 3841                    RUA MUNDO NOVO    133            CANUDOS  93548000
# 3997              RUA SETE DE SETEMBRO    842             CENTRO  93800000
# 8815    AVENIDA JOAO PEREIRA DE VARGAS   2017      NOVA SAPUCAIA  93224150
# 8819    AVENIDA JOAO PEREIRA DE VARGAS   1413         PASQUALINI  93224150
# 11254          AVENIDA SANTOS FERREIRA   1300    MARECHAL RONDON  92020478
# 11383  AVENIDA GENERAL FLORES DA CUNHA   1617        VILA IMBUHY  94910002
# 13682               AVENIDA ELY CORREA   2543      SÍTIO SOBRADO  94180130
# 13767                     AVENIDA MAUA   5310             VARGAS  93218270
# 14144           AVENIDA SILVIO FREITAS      4  MORADA DO VALE II  94120150
# ...
